# %%
import requests
import pandas as pd
import io
import os
import mysql.connector
import hashlib
import pandas as pd
import numpy as np

# %%
earthquake_url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.csv'

# %%
s=requests.get(earthquake_url).content
earthquake_df = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
def create_hash_column(dataframe):
    """
    Create a hash column by combining all other columns in the DataFrame into a string
    and hashing it using SHA-256.

    Args:
        dataframe (pandas.DataFrame): The input DataFrame.

    Returns:
        pandas.DataFrame: The DataFrame with an additional 'hash_column' containing the hash values.
    """
    # Combine all columns into a single string
    combined_string = dataframe.apply(lambda row: ''.join(map(str, row)), axis=1)

    # Create a new column with the hash values
    dataframe['hash_column'] = combined_string.apply(lambda x: hashlib.sha256(x.encode()).hexdigest())

    return dataframe

# %%
earthquake_df = create_hash_column(earthquake_df)

# %%
# clean df Nan
earthquake_df = earthquake_df.fillna(0.00)

# %%
earthquake_df.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2023-09-25T21:48:06.532Z  44.461000 -115.195000  10.00  2.50      ml  16.0
# 1  2023-09-25T18:10:11.669Z  34.070333  -97.432333   6.31  2.51      ml  77.0
# 2  2023-09-25T17:03:19.290Z  17.988500  -66.854167  11.53  2.50      md   4.0
# 3  2023-09-25T16:42:01.180Z  17.954833  -66.843833  12.06  2.47      md   7.0
# 4  2023-09-25T16:00:12.820Z  19.333167 -155.143500   1.25  3.02      ml  48.0
#
#      gap     dmin   rms  ...                            place        type  \
# 0   63.0  0.68600  0.24  ...       33 km NW of Stanley, Idaho  earthquake
# 1   46.0  0.00000  0.37  ...      10 km S of Wilson, Oklahoma  earthquake
# 2  164.0  0.02737  0.18  ...  3 km SE of Palomas, Puerto Rico  earthquake
# 3  207.0  0.03926  0.11  ...  5 km SSW of Indios, Puerto Rico  earthquake
# 4   91.0  0.00000  0.17  ...   14 km S of Fern Forest, Hawaii  earthquake
#
#   horizontalError depthError  magError  magNst    status  locationSource  \
# 0            1.91      2.012  0.081000    20.0  reviewed              us
# 1            0.00      0.900  0.240000    22.0  reviewed              ok
# 2            4.72      2.140  0.241869     3.0  reviewed              pr
# 3            0.75      0.510  0.180713     5.0  reviewed              pr
# 4            0.26      0.330  0.176328    42.0  reviewed              hv
#
#    magSource                                        hash_column
# 0         us  b2ce2734dab68d651834a201fcb3a657992790488c0524...
# 1         ok  dee88db0c958cc83035e359502cd4065a4229a9e81dede...
# 2         pr  ddb22372ed76e72e315e8d6219998f0c076bcaa1951088...
# 3         pr  730f40cfd688e751df74e18e3638b8331d2db4499746bf...
# 4         hv  7d9c07dab1c042c8eae2aac1bff268899fdceb12342acb...
#
# [5 rows x 23 columns]

# %%
def pandas_to_mysql_type(pandas_type):
    """
    Convert a Pandas data type to its MySQL equivalent.
    
    Args:
        pandas_type (str): The Pandas data type as a string.

    Returns:
        str: The MySQL data type as a string.
    """
    if pandas_type == 'object':
        return 'TEXT'
    elif pandas_type == 'int64':
        return 'INT'
    elif pandas_type == 'float64':
        return 'FLOAT'
    elif pandas_type == 'datetime64':
        return 'DATETIME'
    elif pandas_type == 'bool':
        return 'BOOL'
    else:
        # Handle other cases or raise an error for unsupported types.
        raise ValueError(f"Unsupported Pandas type: {pandas_type}")

def convert_pandas_to_mysql_types(dataframe):
    """
    Convert Pandas column types to MySQL data types for a DataFrame.

    Args:
        dataframe (pd.DataFrame): The Pandas DataFrame to convert.

    Returns:
        dict: A dictionary mapping column names to MySQL data types.
    """
    mysql_types = {}
    for column_name, dtype in dataframe.dtypes.items():
        mysql_type = pandas_to_mysql_type(dtype.name)
        mysql_types[column_name] = mysql_type
    return mysql_types

# %%
mysql_column_types = convert_pandas_to_mysql_types(earthquake_df)

# %%
mysql_column_types
# Out:
# {'time': 'TEXT',
#  'latitude': 'FLOAT',
#  'longitude': 'FLOAT',
#  'depth': 'FLOAT',
#  'mag': 'FLOAT',
#  'magType': 'TEXT',
#  'nst': 'FLOAT',
#  'gap': 'FLOAT',
#  'dmin': 'FLOAT',
#  'rms': 'FLOAT',
#  'net': 'TEXT',
#  'id': 'TEXT',
#  'updated': 'TEXT',
#  'place': 'TEXT',
#  'type': 'TEXT',
#  'horizontalError': 'FLOAT',
#  'depthError': 'FLOAT',
#  'magError': 'FLOAT',
#  'magNst': 'FLOAT',
#  'status': 'TEXT',
#  'locationSource': 'TEXT',
#  'magSource': 'TEXT',
#  'hash_column': 'TEXT'}

# %%
#create table 
table_name = 'portfolio.earthquake_table'
create_table_sql = f"CREATE TABLE {table_name} ("

for column_name, mysql_type in mysql_column_types.items():
    create_table_sql += f"{column_name} {mysql_type}, "

# Remove the trailing comma and space
create_table_sql = create_table_sql[:-2]

create_table_sql += ");"

# %%
create_table_sql
# Out:
# 'CREATE TABLE portfolio.earthquake_table (time TEXT, latitude FLOAT, longitude FLOAT, depth FLOAT, mag FLOAT, magType TEXT, nst FLOAT, gap FLOAT, dmin FLOAT, rms FLOAT, net TEXT, id TEXT, updated TEXT, place TEXT, type TEXT, horizontalError FLOAT, depthError FLOAT, magError FLOAT, magNst FLOAT, status TEXT, locationSource TEXT, magSource TEXT, hash_column TEXT);'

# %%
connection = mysql.connector.connect(
        host=os.environ["MYSQL_ENDPOINT"],
        user=os.environ["MYSQL_USER"],
        password=os.environ["MYSQL_PASS"]
    )

# %%
cursor = connection.cursor()

# %%
cursor.execute(create_table_sql)

# %%
columns = ', '.join(mysql_column_types.keys())
placeholders = ', '.join(['%s'] * len(mysql_column_types))
insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"

# %%
cursor.close()
# Out:
# True

# %%
cursor = connection.cursor()

# %%
#insert into table
for index, row in earthquake_df.iterrows():
    values = [row[column] for column in mysql_column_types.keys()]
    print(values)
    cursor.execute(insert_sql, values)
# Out:
# ['2023-09-25T21:48:06.532Z', 44.461, -115.195, 10.0, 2.5, 'ml', 16.0, 63.0, 0.686, 0.24, 'us', 'us7000ky20', '2023-09-25T22:16:12.040Z', '33 km NW of Stanley, Idaho', 'earthquake', 1.91, 2.012, 0.081, 20.0, 'reviewed', 'us', 'us', 'b2ce2734dab68d651834a201fcb3a657992790488c05245bb2040a2f1f40b305']
# ['2023-09-25T02:25:39.470Z', 19.1476, -64.6046, 37.0, 3.6, 'md', 12.0, 302.0, 0.8696, 0.5, 'pr', 'pr2023268000', '2023-09-25T03:01:44.742Z', '92 km NNE of Cruz Bay, U.S. Virgin Islands', 'earthquake', 4.8, 29.61, 0.16, 3.0, 'reviewed', 'pr', 'pr', '32dd329a8641178a2c6ddd79225db4be503b2a421972f25f8140ab36dad53dd7']
# ['2023-09-25T01:28:57.490Z', 17.9311666666667, -66.8481666666667, 12.69, 2.6, 'md', 8.0, 218.0, 0.05274, 0.1, 'pr', 'pr71425748', '2023-09-25T01:45:11.080Z', '6 km SE of Maria Antonia, Puerto Rico', 'earthquake', 0.68, 0.84, 0.0412395138847614, 6.0, 'reviewed', 'pr', 'pr', '272fd81e733638771ed7b005b4b290be10eb45eb2e78556879bdf4688e00fbab']
# ['2023-09-25T01:23:00.710Z', 17.9401666666667, -66.9365, 13.47, 2.97, 'md', 18.0, 215.0, 0.04145, 0.08, 'pr', 'pr71425733', '2023-09-25T01:46:01.500Z', 'Puerto Rico region', 'earthquake', 0.46, 0.23, 0.0887405699273227, 5.0, 'reviewed', 'pr', 'pr', '918b1dda044209c49f0ebcb9fef45c2fe0834c25cc2e412cd85e6acf7aac21e8']
# ['2023-09-25T00:40:31.129Z', 34.48, -97.77266667, 19.89, 3.68, 'ml', 97.0, 47.0, 0.0, 0.36, 'ok', 'ok2023stwr', '2023-09-25T19:01:12.991Z', '9 km WNW of Velma, Oklahoma', 'earthquake', 0.0, 0.7, 0.23, 32.0, 'reviewed', 'ok', 'ok', '4a4129549c8f3f2cfb751c04aff52980f46a7a1c8e2a1e4a61883cd97225326e']
# ['2023-09-24T23:59:29.388Z', 45.7301, -73.4849, 5.178, 2.7, 'mb_lg', 32.0, 82.0, 0.249, 0.58, 'us', 'us7000kxw7', '2023-09-25T20:41:54.430Z', '1 km N of Charlemagne, Canada', 'earthquake', 5.2, 7.726, 0.117, 19.0, 'reviewed', 'us', 'us', 'ef9d8369ef3443a42473a7c84b1016735c3394b3ecd169b8d2b497f76d89c4de']
# ['2023-09-24T23:50:39.710Z', -14.4765, 173.6373, 611.429, 4.5, 'mb', 89.0, 48.0, 5.345, 0.52, 'us', 'us7000kxw5', '2023-09-25T01:06:23.040Z', 'Fiji region', 'earthquake', 11.53, 7.455, 0.037, 214.0, 'reviewed', 'us', 'us', '3d06815b7cb4620822148e0bb0bf9c163c20a6531933dedf076bb74cc75b68ec']

# %%
connection.commit()

# %%
cursor.close()
# Out:
# True

# %% [markdown]
# Workflow for Upserting into DB
#
# 1 . Get current hash List
#
# 2. Filter on DB download from API
#
# 3. Create insert statments of Hases that ARE NOT currently in DB
#
# 4. Insert and Commit Rows
#
# 5. Close Cursor and end funtion.

# %%
#upsert
cursor = connection.cursor()

# %%
# 32  2023-09-25T02:44:15.618Z  53.307200  159.648300   70.8950  4.30
# 33  2023-09-25T02:25:39.470Z  19.147600  -64.604600   37.0000  3.60
# 34  2023-09-25T01:28:57.490Z  17.931167  -66.848167   12.6900  2.60
# 35  2023-09-25T01:28:54.406Z  -1.094500   10.262500   10.0000  4.60
# 36  2023-09-25T01:23:00.710Z  17.940167  -66.936500   13.4700  2.97
# 37  2023-09-25T00:40:31.129Z  34.480000  -97.772667   19.8900  3.68
# 38  2023-09-24T23:59:29.388Z  45.730100  -73.484900    5.1780  2.70
# 39  2023-09-24T23:50:39.710Z -14.476500  173.637300  611.4290  4.50
#
#        magType    nst    gap      dmin   rms  ...  \
# 0           md   16.0  214.0   0.07298  0.08  ...
# 1           md   24.0  219.0   0.08378  0.18  ...
# 2           ml   16.0   63.0   0.68600  0.24  ...
# 3           ml   77.0   46.0   0.00000  0.37  ...
# 4           md    4.0  164.0   0.02737  0.18  ...
# 5           md    7.0  207.0   0.03926  0.11  ...
# 6           ml   48.0   91.0       NaN  0.17  ...
# 7           mb   51.0   87.0   2.41400  0.67  ...
# 8           md    5.0  145.0   0.03421  0.10  ...
# 9           mb   57.0  182.0   2.31600  0.85  ...
# 10          mb   37.0   97.0   2.18500  0.75  ...
# 11          md    4.0  253.0   0.11340  0.17  ...
# 12          md   47.0   54.0   0.02458  0.19  ...
# 13  ml(texnet)   15.0   71.0   0.00000  0.20  ...
# 14          md    7.0  215.0   0.04831  0.08  ...
# 15          md   11.0   77.0   0.09745  0.28  ...
# 16          mb  129.0  166.0   2.05400  0.90  ...
# 17          ml   66.0   42.0   0.10360  0.32  ...
# 18          mb   43.0   87.0   1.87700  0.57  ...
# 19          md    6.0  238.0   0.19940  0.07  ...
# 20          ml    NaN    NaN       NaN  0.54  ...
# 21          mb   76.0  109.0   0.21300  0.40  ...
# 22          mb   18.0  101.0   1.45400  0.68  ...
# 23          mb   47.0   85.0   3.67200  0.46  ...
# 24          mb   64.0   83.0   2.72500  0.48  ...
# 25          mb   48.0  148.0   1.00000  0.45  ...
# 26          md   12.0  209.0   0.04152  0.19  ...
# 27          mb   60.0   79.0   4.96500  0.48  ...
# 28          md   18.0  264.0   0.18970  0.20  ...
# 29  ml(texnet)   21.0   45.0   0.00000  0.10  ...
# 30          mb   73.0   56.0   1.30900  0.78  ...
# 31  ml(texnet)   17.0   53.0   0.10000  0.10  ...
# 32          mb   28.0  153.0   0.66500  0.54  ...
# 33          md   12.0  302.0   0.86960  0.50  ...
# 34          md    8.0  218.0   0.05274  0.10  ...
# 35          mb   47.0   71.0  16.94700  0.48  ...
# 36          md   18.0  215.0   0.04145  0.08  ...
# 37          ml   97.0   47.0   0.00000  0.36  ...
# 38       mb_lg   32.0   82.0   0.24900  0.58  ...
# 39          mb   89.0   48.0   5.34500  0.52  ...
#
#                                                 place        type  \
# 0               8 km SE of Maria Antonia, Puerto Rico  earthquake
# 1             10 km SSE of Maria Antonia, Puerto Rico  earthquake
# 2                          33 km NW of Stanley, Idaho  earthquake
# 3                         10 km S of Wilson, Oklahoma  earthquake
# 4                     3 km SE of Palomas, Puerto Rico  earthquake
# 5                     5 km SSW of Indios, Puerto Rico  earthquake
# 6                      14 km S of Fern Forest, Hawaii  earthquake
# 7                                           Banda Sea  earthquake
# 8                     2 km SE of Palomas, Puerto Rico  earthquake
# 9                         off the coast of Washington  earthquake
# 10                                          Banda Sea  earthquake
# 11                  12 km SSW of Guánica, Puerto Rico  earthquake
# 12                        12 km SSW of Tres Pinos, CA  earthquake
# 13                     6 km WNW of Karnes City, Texas  earthquake
# 14              6 km SE of Maria Antonia, Puerto Rico  earthquake
# 15              4 km NE of Sabana Grande, Puerto Rico  earthquake
# 16                   52 km S of Champerico, Guatemala  earthquake
# 17                              20 km WSW of Taft, CA  earthquake
# 18                            106 km W of Kuqa, China  earthquake
# 19                                 Puerto Rico region  earthquake
# 20  Near the north coast of Chukotskiy Avtonomnyy ...  earthquake
# 21                           128 km W of Adak, Alaska  earthquake
# 22                      Chile-Argentina border region  earthquake
# 23                          south of the Fiji Islands  earthquake
# 24                         Kepulauan Babar, Indonesia  earthquake
# 25                          69 km ENE of Mutsu, Japan  earthquake
# 26                    5 km SSW of Indios, Puerto Rico  earthquake
# 27                      South Sandwich Islands region  earthquake
# 28                18 km N of San Antonio, Puerto Rico  earthquake
# 29                          37 km W of Mentone, Texas  earthquake
# 30                          58 km SSE of Shima, Japan  earthquake
# 31                        31 km WSW of Ackerly, Texas  earthquake
# 32      73 km ENE of Petropavlovsk-Kamchatsky, Russia  earthquake
# 33         92 km NNE of Cruz Bay, U.S. Virgin Islands  earthquake
# 34              6 km SE of Maria Antonia, Puerto Rico  earthquake
# 35                       38 km WNW of Fougamou, Gabon  earthquake
# 36                    4 km SW of Guánica, Puerto Rico  earthquake
# 37                        9 km WNW of Velma, Oklahoma  earthquake
# 38                      1 km N of Charlemagne, Canada  earthquake
# 39                                        Fiji region  earthquake
#
#    horizontalError depthError  magError  magNst     status  locationSource  \
# 0         0.660000   0.350000  0.123629     6.0   reviewed              pr
# 1         0.530000   0.420000  0.120035     6.0   reviewed              pr
# 2         1.910000   2.012000  0.081000    20.0   reviewed              us
# 3              NaN   0.900000  0.240000    22.0   reviewed              ok
# 4         4.720000   2.140000  0.241869     3.0   reviewed              pr
# 5         0.750000   0.510000  0.180713     5.0   reviewed              pr
# 6         0.260000   0.330000  0.176328    42.0   reviewed              hv
# 7         9.020000   2.358000  0.089000    38.0   reviewed              us
# 8         3.030000   1.900000  0.127270     2.0   reviewed              pr
# 9         9.090000   1.988000  0.076000    47.0   reviewed              us
# 10        8.680000   7.830000  0.106000    26.0   reviewed              us
# 11        1.940000   4.710000  0.037029     2.0   reviewed              pr
# 12        0.270000   0.970000  0.150000    55.0  automatic              nc
# 13        1.274076   2.064351  0.200000     9.0   reviewed              tx
# 14        0.840000   0.670000  0.053008     5.0   reviewed              pr
# 15        0.710000   1.200000  0.111121     4.0   reviewed              pr
# 16        9.990000   1.954000  0.033000   280.0   reviewed              us
# 17        0.310000   0.580000  0.118000    75.0   reviewed              ci
# 18        7.670000   1.932000  0.126000    18.0   reviewed              us
# 19        0.790000   1.030000  0.005141     5.0   reviewed              pr
# 20             NaN   3.900000       NaN     NaN   reviewed              ak
# 21       12.260000   6.107000  0.078000    42.0   reviewed              us
# 22       10.500000  11.356000  0.197000     7.0   reviewed              us
# 23        9.040000   6.813000  0.085000    42.0   reviewed              us
# 24       11.040000   7.194000  0.067000    68.0   reviewed              us
# 25        4.500000   8.321000  0.068000    63.0   reviewed              us
# 26        0.790000   0.620000  0.051323     4.0   reviewed              pr
# 27        8.800000   6.431000  0.066000    72.0   reviewed              us
# 28        1.340000   0.700000  0.076532     8.0   reviewed              pr
# 29        0.754513   0.875698  0.000000     7.0   reviewed              tx
# 30        7.330000   6.916000  0.051000   107.0   reviewed              us
# 31        0.851877   2.100788  0.100000     7.0   reviewed              tx
# 32       12.820000   8.946000  0.081000    43.0   reviewed              us
# 33        4.800000  29.610000  0.160000     3.0   reviewed              pr
# 34        0.680000   0.840000  0.041240     6.0   reviewed              pr
# 35       13.830000   1.960000  0.082000    45.0   reviewed              us
# 36        0.460000   0.230000  0.088741     5.0   reviewed              pr
# 37             NaN   0.700000  0.230000    32.0   reviewed              ok
# 38        5.200000   7.726000  0.117000    19.0   reviewed              us
# 39       11.530000   7.455000  0.037000   214.0   reviewed              us
#
#     magSource                                        hash_column
# 0          pr  cdd6186d9c4933d3c9621ebd93c3d396ae706f4cd20a52...
# 1          pr  7c36ef7eab38ec4faf888445cb0e789acb4eaf5ae2ca67...
# 2          us  d95cdf4d815814fee3cecaf1292cab2da2e483f7628c06...
# 3          ok  dee88db0c958cc83035e359502cd4065a4229a9e81dede...
# 4          pr  ddb22372ed76e72e315e8d6219998f0c076bcaa1951088...
# 5          pr  730f40cfd688e751df74e18e3638b8331d2db4499746bf...
# 6          hv  7d9c07dab1c042c8eae2aac1bff268899fdceb12342acb...
# 7          us  7da198cbbf82c6e17bdddfcfd1594b05bdc873f6a6bebd...
# 8          pr  9d5263eb05e61833f32c8fc48f4eb7c67b26bc1b53af2d...
# 9          us  55f66f756306fcc6f3d6924d9a4f32794f358490f0b2a8...
# 10         us  6b6522e49c15f70eec5380d06adfe912660c3aed9373e0...
# 11         pr  bdb9de1522b328c2e72a97e8d33db9d873f3edbb2b71eb...
# 12         nc  b5da3b6766b2022ef581cfab849cdd92656bd2bf944453...
# 13         tx  656b0cb09ae5c7f14e6787231f668ff4ab21cf2e20c983...
# 14         pr  3503211618dc29c03663eb2d042a54ec01faeeb0acca07...
# 15         pr  a08edc43348864243be22a2d74ce810de41044c83df194...
# 16         us  9ea11fa0c066b2b91a78f86ba0a3d793827f0307e80515...
# 17         ci  e746ac4cd9964e2218c1098bd36e453dff12b19e1ab8cd...
# 18         us  fb72c30f66eaca915d77e6867de0f3baed67ffc809964d...
# 19         pr  f2a49efacd256dbcdd5ac4a0c090c114fd4d564dcd89b4...
# 20         ak  dfa5b4cbb8b4aff7688783ab610f27cf0f17a976e07f7c...
# 21         us  7546996d149a2efb98379e762d091694b3fe23693f48be...
# 27  2023-09-25T04:12:19.407Z -55.902700  -28.317700  147.1160  5.00
# 28  2023-09-25T04:11:55.270Z  18.658167  -67.105000   98.3700  3.23
# 29  2023-09-25T04:09:13.835Z  31.719000 -103.998000    6.3372  2.60
# 32  2023-09-25T02:44:15.618Z  53.307200  159.648300   70.8950  4.30
# 33  2023-09-25T02:25:39.470Z  19.147600  -64.604600   37.0000  3.60
# 34  2023-09-25T01:28:57.490Z  17.931167  -66.848167   12.6900  2.60
# 37  2023-09-25T00:40:31.129Z  34.480000  -97.772667   19.8900  3.68
# 38  2023-09-24T23:59:29.388Z  45.730100  -73.484900    5.1780  2.70
# 39  2023-09-24T23:50:39.710Z -14.476500  173.637300  611.4290  4.50
#
#        magType    nst    gap     dmin   rms  ...  \
# 3           ml   77.0   46.0  0.00000  0.37  ...
# 4           md    4.0  164.0  0.02737  0.18  ...
# 5           md    7.0  207.0  0.03926  0.11  ...
# 6           ml   48.0   91.0  0.00000  0.17  ...
# 7           mb   51.0   87.0  2.41400  0.67  ...
# 8           md    5.0  145.0  0.03421  0.10  ...
# 10          mb   37.0   97.0  2.18500  0.75  ...
# 12          md   47.0   54.0  0.02458  0.19  ...
# 15          md   11.0   77.0  0.09745  0.28  ...
# 16          mb  129.0  166.0  2.05400  0.90  ...
# 17          ml   66.0   42.0  0.10360  0.32  ...
# 18          mb   43.0   87.0  1.87700  0.57  ...
# 21          mb   76.0  109.0  0.21300  0.40  ...
# 22          mb   18.0  101.0  1.45400  0.68  ...
# 23          mb   47.0   85.0  3.67200  0.46  ...
# 25          mb   48.0  148.0  1.00000  0.45  ...
# 26          md   12.0  209.0  0.04152  0.19  ...
# 27          mb   60.0   79.0  4.96500  0.48  ...
# 28          md   18.0  264.0  0.18970  0.20  ...
# 29  ml(texnet)   21.0   45.0  0.00000  0.10  ...
# 32          mb   28.0  153.0  0.66500  0.54  ...
# 33          md   12.0  302.0  0.86960  0.50  ...
# 34          md    8.0  218.0  0.05274  0.10  ...
# 37          ml   97.0   47.0  0.00000  0.36  ...
# 38       mb_lg   32.0   82.0  0.24900  0.58  ...
# 39          mb   89.0   48.0  5.34500  0.52  ...
#
#                                             place        type horizontalError  \
# 3                     10 km S of Wilson, Oklahoma  earthquake        0.000000
# 4                 3 km SE of Palomas, Puerto Rico  earthquake        4.720000
# 5                 5 km SSW of Indios, Puerto Rico  earthquake        0.750000
# 6                  14 km S of Fern Forest, Hawaii  earthquake        0.260000
# 7                                       Banda Sea  earthquake        9.020000
# 8                 2 km SE of Palomas, Puerto Rico  earthquake        3.030000
# 10                                      Banda Sea  earthquake        8.680000
# 12                    12 km SSW of Tres Pinos, CA  earthquake        0.270000
# 15          4 km NE of Sabana Grande, Puerto Rico  earthquake        0.710000
# 16               52 km S of Champerico, Guatemala  earthquake        9.990000
# 17                          20 km WSW of Taft, CA  earthquake        0.310000
# 18                        106 km W of Kuqa, China  earthquake        7.670000
# 21                       128 km W of Adak, Alaska  earthquake       12.260000
# 22                  Chile-Argentina border region  earthquake       10.500000
# 23                      south of the Fiji Islands  earthquake        9.040000
# 25                      69 km ENE of Mutsu, Japan  earthquake        4.500000
# 26                5 km SSW of Indios, Puerto Rico  earthquake        0.790000
# 27                  South Sandwich Islands region  earthquake        8.800000
# 28            18 km N of San Antonio, Puerto Rico  earthquake        1.340000
# 29                      37 km W of Mentone, Texas  earthquake        0.754513
# 32  73 km ENE of Petropavlovsk-Kamchatsky, Russia  earthquake       12.820000
# 33     92 km NNE of Cruz Bay, U.S. Virgin Islands  earthquake        4.800000
# 34          6 km SE of Maria Antonia, Puerto Rico  earthquake        0.680000
# 37                    9 km WNW of Velma, Oklahoma  earthquake        0.000000
# 38                  1 km N of Charlemagne, Canada  earthquake        5.200000
# 39                                    Fiji region  earthquake       11.530000
#
#    depthError  magError  magNst     status  locationSource  magSource  \
# 3    0.900000  0.240000    22.0   reviewed              ok         ok
# 4    2.140000  0.241869     3.0   reviewed              pr         pr
# 5    0.510000  0.180713     5.0   reviewed              pr         pr
# 6    0.330000  0.176328    42.0   reviewed              hv         hv
# 7    2.358000  0.089000    38.0   reviewed              us         us
# 8    1.900000  0.127270     2.0   reviewed              pr         pr
# 10   7.830000  0.106000    26.0   reviewed              us         us
# 12   0.970000  0.150000    55.0  automatic              nc         nc
# 15   1.200000  0.111121     4.0   reviewed              pr         pr
# 16   1.954000  0.033000   280.0   reviewed              us         us
# 17   0.580000  0.118000    75.0   reviewed              ci         ci
# 18   1.932000  0.126000    18.0   reviewed              us         us
# 21   6.107000  0.078000    42.0   reviewed              us         us
# 22  11.356000  0.197000     7.0   reviewed              us         us
# 23   6.813000  0.085000    42.0   reviewed              us         us
# 25   8.321000  0.068000    63.0   reviewed              us         us
# 26   0.620000  0.051323     4.0   reviewed              pr         pr
# 27   6.431000  0.066000    72.0   reviewed              us         us
# 28   0.700000  0.076532     8.0   reviewed              pr         pr
# 29   0.875698  0.000000     7.0   reviewed              tx         tx
# 32   8.946000  0.081000    43.0   reviewed              us         us
# 33  29.610000  0.160000     3.0   reviewed              pr         pr
# 34   0.840000  0.041240     6.0   reviewed              pr         pr
# 37   0.700000  0.230000    32.0   reviewed              ok         ok
# 38   7.726000  0.117000    19.0   reviewed              us         us
# 39   7.455000  0.037000   214.0   reviewed              us         us
#
#                                           hash_column
# 3   dee88db0c958cc83035e359502cd4065a4229a9e81dede...
# 4   ddb22372ed76e72e315e8d6219998f0c076bcaa1951088...
# 5   730f40cfd688e751df74e18e3638b8331d2db4499746bf...
# 6   7d9c07dab1c042c8eae2aac1bff268899fdceb12342acb...
# 7   7da198cbbf82c6e17bdddfcfd1594b05bdc873f6a6bebd...
# 8   9d5263eb05e61833f32c8fc48f4eb7c67b26bc1b53af2d...
# 10  6b6522e49c15f70eec5380d06adfe912660c3aed9373e0...
# 12  b5da3b6766b2022ef581cfab849cdd92656bd2bf944453...
# 15  a08edc43348864243be22a2d74ce810de41044c83df194...
# 16  9ea11fa0c066b2b91a78f86ba0a3d793827f0307e80515...
# 17  e746ac4cd9964e2218c1098bd36e453dff12b19e1ab8cd...
# 18  fb72c30f66eaca915d77e6867de0f3baed67ffc809964d...
# 21  7546996d149a2efb98379e762d091694b3fe23693f48be...
# 22  fd7e6b4275c70924791f49798af2995ef6d0f41b530319...
# 23  55a61c0b146a1f15a7b56f653e3ad3f684e5a28e4bf2a7...
# 25  d09b93f814179066cd3ae45d6c2fce80da9ccff7fefdc3...
# 26  5875a5b8a4b581052771668f693f9aaf543804e13593e0...
# 27  a93a6d7e7977932f617da785876029248d29259ba38b5a...
# 28  23e61dbaa8b71e782e8c4a18a1d53f0ce4d1d76da10ed8...
# 29  61a2a29e474af24ecd352e9bd957ebf55e150113f6bf5b...
# 32  aeabcd5b2865f6fab8fef326c66a60ffe6c837f8455cea...
# 33  32dd329a8641178a2c6ddd79225db4be503b2a421972f2...
# 34  272fd81e733638771ed7b005b4b290be10eb45eb2e7855...
# 37  4a4129549c8f3f2cfb751c04aff52980f46a7a1c8e2a1e...
# 38  ef9d8369ef3443a42473a7c84b1016735c3394b3ecd169...
# 39  3d06815b7cb4620822148e0bb0bf9c163c20a6531933de...
#
# [26 rows x 23 columns]

# %%
columns = ', '.join(mysql_column_types.keys())
placeholders = ', '.join(['%s'] * len(mysql_column_types))
insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"

# %%
for index, row in upsert_earthquake_df.iterrows():
    values = [row[column] for column in mysql_column_types.keys()]
    print(values)
    cursor.execute(insert_sql, values)
# Out:
# ['2023-09-25T18:10:11.669Z', 34.07033333, -97.43233333, 6.31, 2.51, 'ml', 77.0, 46.0, 0.0, 0.37, 'ok', 'ok2023svfh', '2023-09-25T21:15:16.753Z', '10 km S of Wilson, Oklahoma', 'earthquake', 0.0, 0.9, 0.24, 22.0, 'reviewed', 'ok', 'ok', 'dee88db0c958cc83035e359502cd4065a4229a9e81dede20923a44aeb986a108']
# ['2023-09-25T17:03:19.290Z', 17.9885, -66.8541666666667, 11.53, 2.5, 'md', 4.0, 164.0, 0.02737, 0.18, 'pr', 'pr71425878', '2023-09-25T17:19:51.500Z', '3 km SE of Palomas, Puerto Rico', 'earthquake', 4.72, 2.14, 0.241869394901518, 3.0, 'reviewed', 'pr', 'pr', 'ddb22372ed76e72e315e8d6219998f0c076bcaa1951088ca536b920c89726d9d']
# ['2023-09-25T16:42:01.180Z', 17.9548333333333, -66.8438333333333, 12.06, 2.47, 'md', 7.0, 207.0, 0.03926, 0.11, 'pr', 'pr71425868', '2023-09-25T16:57:02.100Z', '5 km SSW of Indios, Puerto Rico', 'earthquake', 0.75, 0.51, 0.180713256236441, 5.0, 'reviewed', 'pr', 'pr', '730f40cfd688e751df74e18e3638b8331d2db4499746bf5ef53eabe5d3632eb6']
# ['2023-09-25T16:00:12.820Z', 19.3331666666667, -155.1435, 1.25, 3.02, 'ml', 48.0, 91.0, 0.0, 0.17, 'hv', 'hv73585172', '2023-09-25T22:14:15.892Z', '14 km S of Fern Forest, Hawaii', 'earthquake', 0.26, 0.33, 0.176328479081617, 42.0, 'reviewed', 'hv', 'hv', '7d9c07dab1c042c8eae2aac1bff268899fdceb12342acb326f292d8cce67cbd0']
# ['2023-09-25T04:09:13.835Z', 31.719, -103.998, 6.3372, 2.6, 'ml(texnet)', 21.0, 45.0, 0.0, 0.1, 'tx', 'tx2023sudn', '2023-09-25T15:03:41.392Z', '37 km W of Mentone, Texas', 'earthquake', 0.7545132382, 0.8756983871, 0.0, 7.0, 'reviewed', 'tx', 'tx', '61a2a29e474af24ecd352e9bd957ebf55e150113f6bf5baa700572621b8d273d']
# ['2023-09-25T02:44:15.618Z', 53.3072, 159.6483, 70.895, 4.3, 'mb', 28.0, 153.0, 0.665, 0.54, 'us', 'us7000kxwy', '2023-09-25T04:45:04.040Z', '73 km ENE of Petropavlovsk-Kamchatsky, Russia', 'earthquake', 12.82, 8.946, 0.081, 43.0, 'reviewed', 'us', 'us', 'aeabcd5b2865f6fab8fef326c66a60ffe6c837f8455cea3cdb6add2e73fc3fea']
# ['2023-09-25T02:25:39.470Z', 19.1476, -64.6046, 37.0, 3.6, 'md', 12.0, 302.0, 0.8696, 0.5, 'pr', 'pr2023268000', '2023-09-25T03:01:44.742Z', '92 km NNE of Cruz Bay, U.S. Virgin Islands', 'earthquake', 4.8, 29.61, 0.16, 3.0, 'reviewed', 'pr', 'pr', '32dd329a8641178a2c6ddd79225db4be503b2a421972f25f8140ab36dad53dd7']
# ['2023-09-25T01:28:57.490Z', 17.9311666666667, -66.8481666666667, 12.69, 2.6, 'md', 8.0, 218.0, 0.05274, 0.1, 'pr', 'pr71425748', '2023-09-25T01:45:11.080Z', '6 km SE of Maria Antonia, Puerto Rico', 'earthquake', 0.68, 0.84, 0.0412395138847614, 6.0, 'reviewed', 'pr', 'pr', '272fd81e733638771ed7b005b4b290be10eb45eb2e78556879bdf4688e00fbab']
# ['2023-09-25T00:40:31.129Z', 34.48, -97.77266667, 19.89, 3.68, 'ml', 97.0, 47.0, 0.0, 0.36, 'ok', 'ok2023stwr', '2023-09-25T19:01:12.991Z', '9 km WNW of Velma, Oklahoma', 'earthquake', 0.0, 0.7, 0.23, 32.0, 'reviewed', 'ok', 'ok', '4a4129549c8f3f2cfb751c04aff52980f46a7a1c8e2a1e4a61883cd97225326e']
# ['2023-09-24T23:59:29.388Z', 45.7301, -73.4849, 5.178, 2.7, 'mb_lg', 32.0, 82.0, 0.249, 0.58, 'us', 'us7000kxw7', '2023-09-25T20:41:54.430Z', '1 km N of Charlemagne, Canada', 'earthquake', 5.2, 7.726, 0.117, 19.0, 'reviewed', 'us', 'us', 'ef9d8369ef3443a42473a7c84b1016735c3394b3ecd169b8d2b497f76d89c4de']
# ['2023-09-24T23:50:39.710Z', -14.4765, 173.6373, 611.429, 4.5, 'mb', 89.0, 48.0, 5.345, 0.52, 'us', 'us7000kxw5', '2023-09-25T01:06:23.040Z', 'Fiji region', 'earthquake', 11.53, 7.455, 0.037, 214.0, 'reviewed', 'us', 'us', '3d06815b7cb4620822148e0bb0bf9c163c20a6531933dedf076bb74cc75b68ec']

# %%
connection.commit()
cursor.close()
# Out:
# True
